# %%
nome = "Sérgio"
idade = 50

# %%
print(f"Olá, meu nome é {nome} e tenho {idade} anos.")
# Out:
# Olá, meu nome é Sérgio e tenho 50 anos.

# %%
resultados = [
    {"modelo": "GPT-4", "acuracia": 0.92, "tempo_resposta": 1.2},
    {"modelo": "Claude", "acuracia": 0.95, "tempo_resposta": 0.9},
    {"modelo": "Llama", "acuracia": 0.88, "tempo_resposta": 1.5},
]
for r in resultados:
    print(f"{r['modelo']}: acurácia {r['acuracia']*100}%, tempo {r['tempo_resposta']}s")
# Out:
# GPT-4: acurácia 92.0%, tempo 1.2s
# Claude: acurácia 95.0%, tempo 0.9s
# Llama: acurácia 88.0%, tempo 1.5s
